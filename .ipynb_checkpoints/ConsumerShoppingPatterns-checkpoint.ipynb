# %% [markdown]
# # Consumer Shopping Patterns Analysis:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Preparation and Modeling:

# %%
df = pd.read_csv("customer_shopping_behavior.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
# see how many null values:
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %% [markdown]
# Why Median > Mean:
# - Because Mean being more expressed can result in more outliers with dataset.
# - Median is robust with outliers.
# - By Filtering out the data with 'Category' and filling missing values with median reduces bias with dataset.
# - Impute missing values with median values based off 'Category'.

# %%
df.groupby('Category')['Review Rating'].median()
# Out:
# Category
# Accessories    3.8
# Clothing       3.7
# Footwear       3.8
# Outerwear      3.8
# Name: Review Rating, dtype: float64

# %%
# fill missing values with median values for each category:
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.750051
# std    1125.977353    15.207589              23.685392       0.713590
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# - Best for the data columns to adapt snake casing: 'Customer ID' instead 'customer_id'

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df = df.rename(columns={'purchase_amount_(usd)': 'purchase_amount'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             3900 non-null   int64
#  1   age                     3900 non-null   int64
#  2   gender                  3900 non-null   object
#  3   item_purchased          3900 non-null   object
#  4   category                3900 non-null   object
#  5   purchase_amount         3900 non-null   int64
#  6   location                3900 non-null   object
#  7   size                    3900 non-null   object
#  8   color                   3900 non-null   object
#  9   season                  3900 non-null   object
#  10  review_rating           3900 non-null   float64
#  11  subscription_status     3900 non-null   object
#  12  shipping_type           3900 non-null   object
#  13  discount_applied        3900 non-null   object
# ...

# %%
# create a age_group column:
labels = ['Young Adult', 'Adult', 'Middled-aged', 'Senior']
df['age_group'] = pd.qcut(df['age'], q=4, labels=labels)
df[['age', 'age_group']]
# Out:
#       age     age_group
# 0      55  Middled-aged
# 1      19   Young Adult
# 2      50  Middled-aged
# 3      21   Young Adult
# 4      45  Middled-aged
# ...   ...           ...
# 3895   40         Adult
# 3896   52  Middled-aged
# 3897   46  Middled-aged
# 3898   44         Adult
# 3899   52  Middled-aged
#
# [3900 rows x 2 columns]

# %%
# create purchase_frequency_days column - convert text format to numeric format
df['frequency_of_purchases'].value_counts()
# Out:
# frequency_of_purchases
# Every 3 Months    584
# Annually          572
# Quarterly         563
# Monthly           553
# Bi-Weekly         547
# Fortnightly       542
# Weekly            539
# Name: count, dtype: int64

# %%
# create frequency mapping based on days - text to numeric
frequency_mapping = {
    'Fortnightly': 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months': 90
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)
df
# Out:
#       customer_id  age  gender item_purchased     category  purchase_amount  \
# 0               1   55    Male         Blouse     Clothing               53
# 1               2   19    Male        Sweater     Clothing               64
# 2               3   50    Male          Jeans     Clothing               73
# 3               4   21    Male        Sandals     Footwear               90
# 4               5   45    Male         Blouse     Clothing               49
# ...           ...  ...     ...            ...          ...              ...
# 3895         3896   40  Female         Hoodie     Clothing               28
# 3896         3897   52  Female       Backpack  Accessories               49
# 3897         3898   46  Female           Belt  Accessories               33
# 3898         3899   44  Female          Shoes     Footwear               77
# 3899         3900   52  Female        Handbag  Accessories               81
#
# ...

# %%
df[['frequency_of_purchases', 'purchase_frequency_days']]
# Out:
#      frequency_of_purchases  purchase_frequency_days
# 0               Fortnightly                       14
# 1               Fortnightly                       14
# 2                    Weekly                        7
# 3                    Weekly                        7
# 4                  Annually                      365
# ...                     ...                      ...
# 3895                 Weekly                        7
# 3896              Bi-Weekly                       14
# 3897              Quarterly                       90
# 3898                 Weekly                        7
# 3899              Quarterly                       90
#
# [3900 rows x 2 columns]

# %%
df[['discount_applied', 'promo_code_used']]
# Out:
#      discount_applied promo_code_used
# 0                 Yes             Yes
# 1                 Yes             Yes
# 2                 Yes             Yes
# 3                 Yes             Yes
# 4                 Yes             Yes
# ...               ...             ...
# 3895               No              No
# 3896               No              No
# 3897               No              No
# 3898               No              No
# 3899               No              No
#
# [3900 rows x 2 columns]

# %% [markdown]
# - Note: 'discount_applied' and 'promo_code_used' columns look the same.

# %%
(df['discount_applied'] == df['promo_code_used']).all()
# Out:
# True

# %% [markdown]
# - Solution: is to remove one of the columns.

# %%
# removing 'promo_code_used' column:
df = df.drop('promo_code_used', axis=1)
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='object')

# %% [markdown]
# # Data Exploration:

# %% [markdown]
# How can the company leverage consumer shopping data to identify trends, improve customer engagement, and optimize marketing and product strategies?:

# %%
# Which shopping category is more preferred by the customer? Want understand spread, skew, peaks.:
sns.histplot(df, x='purchase_amount', hue='category', multiple='stack')
# Out:
# <Axes: xlabel='purchase_amount', ylabel='Count'>

# %% [markdown]
# - Based off this graph, you can tell that the clothing and accessories categories had more purchases. No skewness.
# - Business Decision: Is to try to increase numbers in Footwear and Outwear.

# %%
# Is the customer more likely use discount for each purchase?:
sns.histplot(df, x='purchase_amount', hue='discount_applied', multiple='stack')
# Out:
# <Axes: xlabel='purchase_amount', ylabel='Count'>

# %% [markdown]
# - Customer is less likely to use discount with each purchase.
# - Business Decision: Is advertise discounts for items.

# %%
# Is the customer more likely use subscription status for each purchase?:
sns.histplot(df, x='purchase_amount', hue='subscription_status', multiple='stack')
# Out:
# <Axes: xlabel='purchase_amount', ylabel='Count'>

# %% [markdown]
# - Customer is less likely to use the subscription status for a purchase.
# - Business Decision: Is to advertise the subscription status more.

# %%
# Compare the reviews distribution based off category?:
fig = plt.figure(figsize=(10, 7))
sns.boxplot(x='category', y='review_rating', hue='gender', data=df)
# Out:
# <Axes: xlabel='category', ylabel='review_rating'>

# %% [markdown]
# - There is no distribution among reviews based off seasons.

# %%
# View how content a customer is with item based off the season and category:
fig = plt.figure(figsize=(15, 10))
sns.lineplot(data=df, x='season', y='review_rating', hue='category', errorbar=None)
# Out:
# <Axes: xlabel='season', ylabel='review_rating'>

# %% [markdown]
# - Customers do not like the Summer Clothing compared to Summer Footwear.
# - Fall and Winter Footwear had the highest review ratings.
# - Business Decision: The company should try to put more time in Summer Clothing category to try to increase the rating.

# %%
# distribution between purchase amount among season and gender:
fig = plt.figure(figsize=(15, 10))
sns.displot(df, x='purchase_amount', col='category', row='gender')

# %% [markdown]
# - The Male Clothing and Accessories category had more purchases.
# - While, the Female Footwear and Outwear is behind compared to Male category.
# - Business Decision: is to try to get Female Categorries at the same level as Male, by putting more resources into Female categories.

# %% [markdown]
# # Make a Connection with PostgreSQL:

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 22.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
# Step 1: Connect to PostgreSQL
# Replace placeholders with your actual details
username = "postgres" # default user
password = "goldeagle" # the password you set during installation
host = "localhost" # if running locally
port = "5432" # default PostgreSQL port
database = "customer_behavior" # the database you created in pgAdmin

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Step 2: Load DataFrame into PostgreSQL
table_name = "customer" # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'customer' in database 'customer_behavior'.
